# %%
from src import load_data
from src import plotting_data
import glob

# Note: Change the path so it reflects how to access the folder train.242
# Also note: This process will take multiple minutes as the files are large, could take upwards of ten minutes

path = "/Users/Embo/comp-neurosci-crcns-hc18/data/train.242/Train-242.clu*"

clu_list = [10, 12, 13, 2, 5, 8, 9] 

for i in clu_list:
    for clufile in glob.glob(path + str(i)):
        p = plotting_data.plot_tetrode(clufile)
        p
